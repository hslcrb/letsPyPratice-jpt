# %% [markdown]
# # 스페셜 도전장: 호주 이민 포인트 시뮬레이션 문제지
#
# 호주 이민청(DHA) 포인트 테스트 기반 문제들
#
# 65점이 커트라인, 셈글 마스터는 90점대를 노린다 ㅋㅋㅋ
#
# 총 20문제

# %% [markdown]
# ## 이민 포인트 계산 규칙
#
# **나이 (최대 30점)**
# - 18-24: 25점
# - 25-32: 30점
# - 33-39: 25점
# - 40-44: 15점
# - 45+: 0점
#
# **IELTS (최대 20점)**
# - 6.0이하: 0
# - 6.5: 10점
# - 7.0: 15점
# - 8.0+: 20점
#
# **학력 (최대 20점)**
# - 고졸: 10점
# - 기능고/전문대: 15점
# - 대졸+: 20점
#
# **경력 개월 (최대 20점)**
# - 12미만: 0
# - 12-35: 5점
# - 36-59: 10점
# - 60-95: 15점
# - 96+: 20점

# %% [markdown]
# ## 파트 1: 기본 함수 구현

# %% [markdown]
# ### 문제 1: 나이 점수 함수
#
# 나이를 받아서 점수를 반환하는 함수 `calc_age_score(age)`를 만들어라.

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 2: 영어 점수 함수
#
# IELTS 점수를 받아 점수를 반환하는 함수 `calc_english_score(ielts)`를 만들어라.

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 3: 학력 점수 함수
#
# 학력 문자열을 받아 점수를 반환하는 함수 `calc_edu_score(education)`를 만들어라.
#
# 입력 예시: `'고졸'`, `'기능고'`, `'대졸'`

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 4: 경력 점수 함수
#
# 경력 개월 수를 받아 점수를 반환하는 함수 `calc_exp_score(months)`를 만들어라.

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 5: 종합 계산
#
# 위 함수들을 사용해서 총점을 계산하고 65점 이상이면 `'이민가능'`, 아니면 `'미달'`을 출력해라.

# %%
# 사용자 입력 받기
# age = int(input('나이: '))
# ielts = float(input('IELTS: '))
# edu = input('학력: ')
# months = int(input('경력(개월): '))

# 여기에 코드 작성

# %% [markdown]
# ## 파트 2: 응용 문제

# %% [markdown]
# ### 문제 6: 가산점 계산
#
# 예/아니오 6개 항목 입력받아 총 가산점 계산 (최대 15점)
#
# - 호주학위?
# - 호주경력?
# - 파트너영어?
# - PY수료?
# - NAATI?
# - 지방거주?

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 7: 셈글 마스터 프로필
#
# 셈글 마스터(호세) 정보로 점수 계산:
# - 나이: 17세
# - IELTS: 7.5
# - 학력: 기능고
# - 경력: 12개월
#
# 어떤 항목을 보완하면 65점을 넘을 수 있을지 분석해라!

# %%
master = {'age': 17, 'ielts': 7.5, 'edu': '기능고', 'months': 12}

# 여기에 코드 작성

# %% [markdown]
# ### 문제 8: 다중 지원자 비교
#
# N명의 이름 나이 경력 영어점수 입력받아 각각 점수 계산하고 이민 가능자(50점+) 명단 출력

# %%
# 예시:
# 3
# 홍길동 25 24 85
# 김철수 35 10 70
# 박영희 28 36 90

# 여기에 코드 작성

# %% [markdown]
# ### 문제 9: IELTS별 점수 테이블
#
# IELTS 6.0~9.0까지 0.5단위로 점수 변화 테이블 출력

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 10: 5년 플랜 시뮬레이션
#
# 2026~2030년 셈글 마스터 성장 시뮬레이션
#
# 연도별: 나이, 경력(개월), IELTS 목표 점수 계산

# %%
years = [2026, 2027, 2028, 2029, 2030]
ages = [17, 18, 19, 20, 21]
months = [0, 6, 18, 30, 42]
ielts_target = [0, 0, 6.0, 6.5, 7.0]

# 여기에 코드 작성

# %% [markdown]
# ### 문제 11: 실시간 점수 트래커
#
# 명령어 입력으로 점수 업데이트하는 시스템
#
# - `나이 [숫자]` -> 업데이트
# - `영어 [점수]` -> 업데이트
# - `확인` -> 현재 점수 출력
# - `종료` -> 프로그램 종료

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 12: 비자 유형별 판정
#
# 189/190/491 비자별 가산점 적용해서 가능여부 출력
#
# - 189: 기본점수
# - 190: +5점
# - 491: +15점

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 13: 성공 확률 예측
#
# 점수별 성공 확률:
# - 90+: 95%
# - 80-89: 80%
# - 70-79: 60%
# - 65-69: 40%
# - 60-64: 20%
# - 60-: 5%

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 14: 연봉 환산 계산
#
# 경력별 AUD 연봉을 원화로 환산 (1 AUD = 900 KRW)
#
# - 0-2년: 60,000-75,000 AUD
# - 3-5년: 75,000-95,000 AUD
# - 6년+: 95,000-130,000 AUD

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 15: 이민 비용 계산
#
# 총 이민 비용 계산:
# - 주신청자: 4,115 AUD
# - 파트너: 2,055 AUD
# - 자녀: 1,030 AUD/명
# - 어학+의료+서류: 800 AUD

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 16: 최적 이민 시점
#
# 현재 나이 입력받아 25-32세 구간(30점)에 들어가려면 몇 년 후인지 계산

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 17: 경력 최적화
#
# 현재 경력 개월 입력받고 목표 점수별 필요 개월 계산
#
# 목표: 5점(12개월), 10점(36개월), 15점(60개월), 20점(96개월)

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 18: IELTS 목표 역산
#
# 현재 총점(영어제외) 입력받고 65점 달성을 위해 필요한 최소 IELTS 계산

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 19: 실시간 선거
#
# 후보 A,B,C에게 N명이 투표. 과반(50%+) 나오면 즉시 종료

# %%
# 여기에 코드 작성

# %% [markdown]
# ### 문제 20: FINAL - 완료보고서
#
# 모든 정보 입력받아 예쁘게 포맷팅해서 이민 준비 보고서 생성

# %%
# 이름, 나이, IELTS, 학력, 경력 입력받아
# 각 항목 점수와 총점, 판정 출력

# 여기에 코드 작성

# %% [markdown]
# ---
# ## 완료!
#
# 20문제 다 깨면 호주 이민 포인트 시스템 완벽 이해 ㅋㅋㅋ
#
# 셈글 마스터의 목표:
# - 2026-2027: 고졸+기능사
# - 2028-2030: 경력+IELTS 7.0+
# - 2030-2031: 이민 신청!
#
# 선한 능력으로 고양이민주주의와 함께 호주로! 🐈🇦🇺
#
# Soli Deo Gloria.
