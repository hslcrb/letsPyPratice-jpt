# %% [markdown]
# # 셈글 파이썬 Level 2 보충: 문자열 & 리스트 문제지
#
# 기초 30문제 깨고도 허전한 후배들을 위한 추가 특식 ㅋㅋㅋ
# 문자열과 리스트 기초를 쳐바른다.
#
# 총 30문제 - BOJ 1차원 배열 단계 참고
#
# **주의**: 각 셀의 `# 여기에 코드 작성` 부분에 직접 코드를 작성하라!

# %% [markdown]
# ## Part 1: 문자열 기초 (10문제)

# %% [markdown]
# ### Q1. 문자열 길이 (BOJ 2743)
#
# 단어를 입력받아 길이를 출력해라. `len()` 함수가 핵심이다 ㅋㅋㅋ
#
# **예시**:
# ```
# 입력: pulljima
# 출력: 8
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q2. 아스키 코드 변환 (BOJ 11654)
#
# 문자를 입력받아 아스키 코드 번호로 변환해라. `ord()` 함수를 써라 ㅋㅋㅋ
#
# **예시**:
# ```
# 입력: A
# 출력: 65
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q3. 숫자의 합 (BOJ 11720)
#
# N개의 숫자가 공백없이 주어지면 각 자리 숫자의 합을 구해라. 문자열 인덱싱이 핵심!
#
# **예시**:
# ```
# 입력: 54321
# 출력: 15
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q4. 알파벳 찾기 (BOJ 10809)
#
# 단어에서 a~z 각 알파벳이 처음 등장하는 위치를 출력. 없으면 -1. `find()` 메서드를 써라 ㅋㅋㅋ
#
# **예시**:
# ```
# 입력: baekjoon
# 출력: 1 0 -1 -1 2 -1 -1 -1 ...
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q5. 문자열 반복 (BOJ 2675)
#
# 각 문자를 R번 반복해서 새 문자열을 만들어라. 중첩 for문 연습하기 좋다 ㅋㅋㅋ
#
# **예시**:
# ```
# 입력: 3 ABC
# 출력: AAABBBCCC
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q6. 단어의 개수 (BOJ 1152)
#
# 영어 대소문자와 공백으로 이루어진 문자열에서 단어 개수를 세어라. `split()` 기본 중의 기본!
#
# **예시**:
# ```
# 입력: The Curious Case of Benjamin Button
# 출력: 6
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q7. 상수 (BOJ 2908)
#
# 숫자 두 개를 뒤집어서 큰 수를 출력해라. `[::-1]` 슬라이싱 쓰면 1초 컷 ㅋㅋㅋ
#
# **예시**:
# ```
# 입력: 734 893
# 출력: 437
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q8. 다이얼 (BOJ 5622)
#
# 전화번호를 걸기 위해 필요한 최소 시간을 계산해라. ABC=3초, DEF=4초... 딕셔너리 써도 되고 if-elif 써도 된다!
#
# **예시**:
# ```
# 입력: WA
# 출력: 13
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q9. 크로아티아 알파벳 (BOJ 2941)
#
# 크로아티아 특수 알파벳(c=, dz=, d-, lj, nj, s=, z=)을 한 글자로 칠 때 총 몇 글자인지 세라. `replace()`로 미리 처리해라!
#
# **예시**:
# ```
# 입력: ljes=njak
# 출력: 6
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q10. 그룹 단어 체커 (BOJ 1316)
#
# 그룹 단어(같은 글자가 연속해서 나오는 단어) 개수를 세어라. 리스트로 방문 체크하는 게 핵심!
#
# **예시**:
# ```
# 입력: 3
# happy
# new
# year
# 출력: 3
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ---
# ## Part 2: 리스트(배열) 기초 (10문제)

# %% [markdown]
# ### Q11. 개수 세기 (BOJ 10807)
#
# N개의 정수 중에서 v가 몇 개 있는지 세어라. `count()` 메서드를 써라 ㅋㅋㅋ
#
# **예시**:
# ```
# 입력: 11
# 1 4 1 2 4 2 4 2 3 4 4
# 2
# 출력: 3
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q12. X보다 작은 수 (BOJ 10871)
#
# 정수 N개로 이루어진 수열에서 X보다 작은 수를 모두 출력해라.
#
# **예시**:
# ```
# 입력: 10 5
# 1 10 4 9 2 3 8 5 7 6
# 출력: 1 4 2 3
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q13. 최소, 최대 (BOJ 10818)
#
# N개의 정수 중 최솟값과 최댓값을 구해라. `min()`, `max()` 함수를 써도 되고 직접 비교해도 된다!
#
# **예시**:
# ```
# 입력: 5
# 20 10 35 30 7
# 출력: 7 35
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q14. 최댓값 (BOJ 2562)
#
# 9개의 서로 다른 자연수 중 최댓값을 찾고, 그게 몇 번째 수인지 출력해라. `index()` 메서드 활용!
#
# **예시**:
# ```
# 입력: 3 29 38 12 57 74 40 85 61
# 출력: 85
# 8
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q15. 공 넣기 (BOJ 10810)
#
# N개의 바구니에 M번 공을 넣는다. i번 바구니부터 j번 바구니까지 k번 번호가 적힌 공을 넣어라. 초기값은 0!
#
# **예시**:
# ```
# 입력: 5 4
# 1 2 3
# 3 4 4
# 1 4 1
# 2 2 2
# 출력: 1 2 1 1 0
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q16. 공 바꾸기 (BOJ 10813)
#
# M번 두 바구니의 공을 교환한다. i번과 j번 바구니의 공을 바꿔라. 다중 할당 활용!
#
# **예시**:
# ```
# 입력: 5 4
# 1 2
# 3 4
# 1 4
# 2 2
# 출력: 3 1 4 2 5
# ```

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q17. 과제 안 내신 분..? (BOJ 5597)
#
# 30명 중 28명의 출석번호가 주어질 때, 과제 안 낸 2명의 출석번호를 작은 순서로 출력해라. ㅋㅋㅋ
#
# **팁**: 1~30 셋트 만들고 차집합 구하면 끝!

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q18. 나머지 (BOJ 3052)
#
# 수 10개를 입력받은 뒤, 42로 나눈 나머지 중 서로 다른 값이 몇 개 있는지 출력해라. `set()` 쓰면 중복 자동 제거!

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q19. 바구니 뒤집기 (BOJ 10811)
#
# 바구니 i번부터 j번까지의 순서를 뒤집어라. 슬라이싱 `[::-1]` 활용!

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q20. 평균 (BOJ 1546)
#
# 시험 본 과목의 개수 N과 각 과목의 점수가 주어진다. 점수 중 최고점 M을 골라 모든 점수를 `점수/M*100`으로 계산한 새로운 평균을 출력해라.

# %%
# 여기에 코드 작성

# %% [markdown]
# ---
# ## Part 3: 셈글 실전 시나리오 (10문제)

# %% [markdown]
# ### Q21. 바리스타 메모 파싱
#
# 바리스타 호세가 남긴 주문 메모가 있다: `"아메리카노3,에스프레소2,라떼1"`
# 쉼표로 분리하고, 각 메뉴의 총 잔수를 구해라.
#
# **힌트**: `split(',')` -> 각 항목에서 숫자만 추출해서 더하기

# %%
# 여기에 코드 작성
memo = "아메리카노3,에스프레소2,라떼1"

# %% [markdown]
# ### Q22. 고양이민주주의 투표 집계
#
# 투표 결과 리스트가 주어진다: `['찬성', '반대', '찬성', '찬성', '반대', '찬성']`
# 찬성이 반대보다 많으면 `"고양이민주주의 통과!"`, 아니면 `"선동 detected..."` 출력!

# %%
# 여기에 코드 작성
votes = ['찬성', '반대', '찬성', '찬성', '반대', '찬성']

# %% [markdown]
# ### Q23. 원전 가동 로그 분석
#
# 10일간의 원전 출력률(%)이 리스트로 주어진다.
# 평균 출력률이 90% 이상이면 `"에너지 안보 확보!"`, 아니면 `"점검 필요"` 출력해라.

# %%
# 여기에 코드 작성
output_rates = [92, 88, 95, 91, 89, 94, 90, 87, 93, 96]

# %% [markdown]
# ### Q24. 요트 항해 체크포인트
#
# 호주 크리스탈 워터스로 가는 항로의 체크포인트 좌표가 문자열로 주어진다: `"23.5,151.2;24.1,152.0;25.0,153.5"`
# 세미콜론으로 분리해서 체크포인트가 총 몇 개인지 출력해라 ㅋㅋㅋ

# %%
# 여기에 코드 작성
route = "23.5,151.2;24.1,152.0;25.0,153.5"

# %% [markdown]
# ### Q25. 마스터의 비밀 메시지
#
# 셈글 마스터가 남긴 암호 메시지: 각 단어의 첫 글자만 따서 새 문자열을 만들어라.
# 예: `"고양이 민주주의 세션 마스터"` -> `"고민세마"`

# %%
# 여기에 코드 작성
message = "고양이 민주주의 세션 마스터 호세"

# %% [markdown]
# ### Q26. 커피 원두 재고 관리
#
# 원두 재고 리스트가 있다: `[100, 80, 95, 60, 70]` (각각 아라비카, 로부스타, 콜롬비아, 에티오피아, 케냐)
# 재고가 70 이하인 원두의 인덱스(위치)를 모두 출력해라!

# %%
# 여기에 코드 작성
stocks = [100, 80, 95, 60, 70]

# %% [markdown]
# ### Q27. 공산주의 단어 필터링
#
# 검열할 단어 리스트: `['공산주의', '탈원전', '감성팔이', '위선']`
# 입력 문장에 이 단어들이 포함되어 있으면 `"검열처리"`, 없으면 `"정상"` 출력!

# %%
# 여기에 코드 작성
banned = ['공산주의', '탈원전', '감성팔이', '위선']
text = input("문장 입력: ")

# %% [markdown]
# ### Q28. 학생 점수 통계
#
# 학생 5명의 점수가 공백으로 구분되어 입력된다. 평균, 최고점, 최저점을 출력해라!

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q29. 팰린드롬 체커
#
# 단어를 입력받아 앞뒤가 똑같은지(회문) 확인해라. `"level"`, `"radar"` 같은 거 ㅋㅋㅋ
#
# **힌트**: `s == s[::-1]` 비교하면 끝!

# %%
# 여기에 코드 작성

# %% [markdown]
# ### Q30. FINAL: 마스터의 수능 영어
#
# 셈글 마스터의 영어 단어장: `['abandon', 'ability', 'abolish', 'absolute', 'abstract']`
#
# 1. a로 시작하는 단어만 골라 새 리스트 만들기
# 2. 그 단어들을 모두 대문자로 변환
# 3. 알파벳 순으로 정렬해서 출력
#
# **힌트**: `startswith()`, `upper()`, `sort()` or `sorted()`

# %%
# FINAL BOSS! 여기에 코드 작성
words = ['abandon', 'ability', 'abolish', 'absolute', 'abstract', 'zebra', 'apple']

# %% [markdown]
# ---
# ## 🎉 완료 축하한다!
#
# 30문제 추가 보충까지 깨면 이제 기초는 거의 끝났다 ㅋㅋㅋ
# 다음 단계는 **반복문(for/while)**으로 넘어가자! 고양이민주주의를 위해 계속 전진하라! 🐈
