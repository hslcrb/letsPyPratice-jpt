# %% [markdown]
# # 🧱 셈글 파이썬 '기초 역량 강화' (학생용 프리패스)
#
# 파이썬 별거 없다 ㅋㅋㅋ 마스터의 힌트를 보고 아래 30문제를 하나씩 뽀개보자! 백준 링크도 있으니 직접 채점도 받아봐라 ㅋㅋㅋ

# %% [markdown]
# ### Q1. Hello World (BOJ 2557)
# [문제 링크](https://www.acmicpc.net/problem/2557)
# 세상에 여러분의 존재를 알리는 첫 마디 ㅋㅋㅋ

# %%
# [문제] Hello World! 를 출력해라 ㅋㅋㅋ

# %% [markdown]
# ### Q2. A+B (BOJ 1000)
# [문제 링크](https://www.acmicpc.net/problem/1000)
# 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.

# %%
# [문제] map(int, input().split()) 를 써서 두 숫자를 받고 더해라! ㅋㅋㅋ

# %% [markdown]
# ### Q3. A-B (BOJ 1001)
# [문제 링크](https://www.acmicpc.net/problem/1001)
# 뺄셈의 미학 ㅋㅋㅋ

# %%
# [문제] 뺄셈도 할 줄 알지? ㅋㅋㅋ

# %% [markdown]
# ### Q4. A*B (BOJ 10998)
# [문제 링크](https://www.acmicpc.net/problem/10998)
# 곱셈도 기본 중에 기본이다!

# %%
# [문제] * 연산자를 써라 ㅋㅋㅋ

# %% [markdown]
# ### Q5. A/B (BOJ 1008)
# [문제 링크](https://www.acmicpc.net/problem/1008)
# 나눗셈은 실수가 나올 수 있으니 주의해라 ㅋㅋㅋ

# %%
# [문제] / 연산자를 써라 ㅋㅋㅋ

# %% [markdown]
# ### Q6. 사칙연산 (BOJ 10869)
# [문제 링크](https://www.acmicpc.net/problem/10869)
# A+B, A-B, A*B, A//B(몫), A%B(나머지)를 한 번에 출력!

# %%
# [문제] 총 5줄에 걸쳐 결과를 출력해라 ㅋㅋㅋ

# %% [markdown]
# ### Q7. ??! (BOJ 10926)
# [문제 링크](https://www.acmicpc.net/problem/10926)
# 이미 가입된 아이디라는 말을 듣고 놀라는 마스터 ㅋㅋㅋ '??!'를 붙여라.

# %%
# [문제] 문자열 더하기(+)를 써서 뒤에 ??! 를 붙여라! ㅋㅋㅋ

# %% [markdown]
# ### Q8. 불기 연도를 서기 연도로 (BOJ 18108)
# [문제 링크](https://www.acmicpc.net/problem/18108)
# 불기 연도에 543을 빼면 서기 연도가 된다. 팩트다!

# %%
# [문제] 입력받은 숫자에 543을 빼라 ㅋㅋㅋ

# %% [markdown]
# ### Q9. 꼬마 정민 (BOJ 11382)
# [문제 링크](https://www.acmicpc.net/problem/11382)
# 세 정수 A, B, C를 받아서 더해라. ㅋㅋㅋ

# %%
# [문제] 공백으로 구분된 세 숫자를 받아라! ㅋㅋㅋ

# %% [markdown]
# ### Q10. 곱셈 과정 (BOJ 2588)
# [문제 링크](https://www.acmicpc.net/problem/2588)
# 세 자리 수 곱셈의 중간 과정을 다 보여주는 섬세한 자본주의 계산기 ㅋㅋㅋ

# %%
# [문제] 인덱싱을 써서 각 자리 수에 곱해봐라! ㅋㅋㅋ

# %% [markdown]
# ### Q11. 두 수 비교하기 (BOJ 1330)
# [문제 링크](https://www.acmicpc.net/problem/1330)
# 두 숫자 중에 누가 더 큰지 팩트체크해라 ㅋㅋㅋ

# %%
# [문제] if, elif, else 를 써서 >, <, == 를 출력해라 ㅋㅋㅋ

# %% [markdown]
# ### Q12. 시험 성적 (BOJ 9498)
# [문제 링크](https://www.acmicpc.net/problem/9498)
# 90~100점은 A, 80~89점은 B, 70~79점은 C, 60~69점은 D, 나머지는 F다!

# %%
# [문제] 다중 if 문을 써서 성적을 매겨라 ㅋㅋㅋ

# %% [markdown]
# ### Q13. 윤년 (BOJ 2753)
# [문제 링크](https://www.acmicpc.net/problem/2753)
# 윤년은 4의 배수이면서 100의 배수가 아니거나, 400의 배수일 때다.

# %%
# [문제] 논리 연산자 and와 or를 잘 써야 한다 ㅋㅋㅋ

# %% [markdown]
# ### Q14. 사분면 고르기 (BOJ 14681)
# [문제 링크](https://www.acmicpc.net/problem/14681)
# 좌표 (x, y)가 어느 사분면에 있는지 맞혀라 ㅋㅋㅋ

# %%
# [문제] x와 y의 부호를 판별해라 ㅋㅋㅋ

# %% [markdown]
# ### Q15. 알람 시계 (BOJ 2884)
# [문제 링크](https://www.acmicpc.net/problem/2884)
# 상근이 아침 잠을 깨워주기 위해 45분 일찍 설정하는 배려 ㅋㅋㅋ

# %%
# [문제] m이 45 미만일 때 h를 어떻게 바꿀지 고민해라! ㅋㅋㅋ

# %% [markdown]
# ### Q16. 오븐 시계 (BOJ 2525)
# [문제 링크](https://www.acmicpc.net/problem/2525)
# 요리가 끝나는 시각을 정확히 계산해라! ㅋㅋㅋ

# %%
# [문제] 몫(//)과 나머지(%)를 쓰면 편하다 ㅋㅋㅋ

# %% [markdown]
# ### Q17. 주사위 세개 (BOJ 2480)
# [문제 링크](https://www.acmicpc.net/problem/2480)
# 도박은 나쁘지만 주사위 상금 계산은 코딩 연습에 좋다 ㅋㅋㅋ

# %%
# [문제] 세 수가 같은지, 두 수만 같은지 판별해라! ㅋㅋㅋ

# %% [markdown]
# ### Q18. 삼각형의 성립 조건
# 가장 긴 변의 길이는 나머지 두 변의 합보다 작아야 한다. 팩트다!

# %%
# [문제] sorted() 를 써서 세 변을 정렬한 뒤 비교해봐라 ㅋㅋㅋ

# %% [markdown]
# ### Q19. BMI 계산기 정식 버전
# 몸무게(kg)와 키(cm)를 입력받아 BMI를 계산하고 판정해라.
# BMI = kg / (m * m)

# %%
# [문제] 키가 cm로 들어오니 m로 바꿔서 계산해라! ㅋㅋㅋ

# %% [markdown]
# ### Q20. 시/분/초를 초로 변환
# H M S를 입력받아 총 몇 초인지 출력!

# %%
# [문제] 1시간은 3600초, 1분은 60초라는 진리를 써라 ㅋㅋㅋ

# %% [markdown]
# ### Q21. 몫과 나머지 (BOJ 10869 응용)
# A를 B로 나눈 몫과 나머지를 한 줄에 출력해라.

# %%
# [문제] // 와 % 를 써라 ㅋㅋㅋ

# %% [markdown]
# ### Q22. 십의 자리 숫자 구하기
# 두 자리 이상의 정수를 입력받아 십의 자리 숫자를 출력해라.

# %%
# [문제] 수의 성질을 잘 생각해라 ㅋㅋㅋ

# %% [markdown]
# ### Q23. 문자열 거꾸로 출력
# 간단한 슬라이싱 기술을 써서 거꾸로 뒤집어라!

# %%
# [문제] [::-1] 이라는 슬라이싱 진리를 기억해라 ㅋㅋㅋ

# %% [markdown]
# ### Q24. 평균 점수 구하기
# 국어, 영어, 수학 세 점수를 받아 평균을 내라. (소수점 둘째자리까지)

# %%
# [문제] round() 함수를 쓰면 소수점 관리가 편하다 ㅋㅋㅋ

# %% [markdown]
# ### Q25. 거스름돈 계산 (동전 개수)
# 10000원에서 물건 값을 뺀 거스름돈 중 500원 동전은 몇 개일까?

# %%
# [문제] 몫(//)만 구하면 된다 ㅋㅋㅋ

# %% [markdown]
# ### Q26. 절대값 구하기
# if문을 써서 입력받은 숫자의 절대값을 출력해라.

# %%
# [문제] 0보다 작으면 - 를 붙여서 출력해라 ㅋㅋㅋ

# %% [markdown]
# ### Q27. 문자열 첫 글자 확인
# 입력받은 문자열의 첫 글자가 'A'인지 확인해라 ㅋㅋㅋ

# %%
# [문제] s[0] 이 바로 첫 글자다 ㅋㅋㅋ

# %% [markdown]
# ### Q28. 배수 판별
# A가 B의 배수인지 확인해라! ㅋㅋㅋ

# %%
# [문제] 나머지가 0인지 확인하는 팩트체크! ㅋㅋㅋ

# %% [markdown]
# ### Q29. 구구단 한 단 맛보기 (BOJ 2739 응용)
# 숫자 N을 받아 N*1 부터 N*3 까지 출력해라 (아직 반복문 전이니까 ㅋㅋㅋ)

# %%
# [문제] 포맷팅(f-string)을 써서 예쁘게 출력해봐라 ㅋㅋㅋ

# %% [markdown]
# ### Q30. FINAL TRAINING: 이름과 나이 조합하기
# 이름(str)과 나이(int)를 받아 한 문장으로 출력해라 ㅋㅋㅋ
# 예: "호세 마스터의 나이는 19세입니다."

# %%
# [문제] 마지막 문제다! 완주 축하한다 ㅋㅋㅋ
