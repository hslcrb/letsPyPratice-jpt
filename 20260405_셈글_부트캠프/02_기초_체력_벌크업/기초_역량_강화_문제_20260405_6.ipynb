# %% [markdown]
# # 🧱 셈글 파이썬 '기초 역량 강화' (학생용 프리패스)
#
# 파이썬 별거 없다 ㅋㅋㅋ 마스터의 힌트를 보고 아래 12문제를 하나씩 뽀개보자!

# %% [markdown]
# ### Q1. 이름 출력하기
# 변수에 본인 이름을 넣고 "내 이름은 OO이다 ㅋㅋㅋ" 라고 출력해봐라.

# %%
# [문제] name 이라는 변수를 만들고 print 해라! ㅋㅋㅋ

# %% [markdown]
# ### Q2. 나이 계산기
# 올해 연도(2026)에서 태어난 연도(2008)를 빼서 나이를 계산해라.

# %%
# [문제] 2026 - 2008 + 1 을 계산해서 출력해라! ㅋㅋㅋ

# %% [markdown]
# ### Q3. 초간단 계산기
# 두 숫자 10과 5를 더하고, 빼고, 곱하고, 나눠서 출력해라.

# %%
# [문제] a = 10, b = 5 로 두고 사칙연산을 다 프린트해라! ㅋㅋㅋ

# %% [markdown]
# ### Q4. 삼각형 면적 구하기
# 밑변 10, 높이 5인 삼각형의 면적을 구해라. (밑변 * 높이 / 2)

# %%
# [문제] 수식을 코드로 옮기기만 하면 된다. 팩트야! ㅋㅋㅋ

# %% [markdown]
# ### Q5. 문자열 뻥튀기
# "팩트폭격" 이라는 글자를 5번 반복해서 출력해라.

# %%
# [문제] 문자열에 * 5 를 하면 어떻게 될까? ㅋㅋㅋ

# %% [markdown]
# ### Q6. 행운의 숫자 7?
# 숫자 하나를 입력받아, 그 숫자가 7이면 "럭키 세븐 ㅋㅋㅋ!"을 출력하고 아니면 "가짜 숫자다!"를 출력해라.

# %%
# [문제] int(input()) 으로 숫자를 받고, if 문을 써서 판별해라! ㅋㅋㅋ

# %% [markdown]
# ### Q7. 홀짝 판별기
# 숫자를 입력받아 2로 나눈 나머지가 0이면 "짝수", 아니면 "홀수"라고 출력해라.

# %%
# [문제] % 연산자가 바로 '나머지'를 구하는 거다. ㅋㅋㅋ

# %% [markdown]
# ### Q8. 성적 판독기
# 점수를 입력받아 90점 이상이면 A, 80점 이상이면 B, 그 외엔 F를 출력해라.

# %%
# [문제] if, elif, else 를 다 써야겠지? ㅋㅋㅋ

# %% [markdown]
# ### Q9. 마스터 호세 환영 인사
# 이름을 입력받아 만약 "호세" 이면 "어서오십시오 마스터 ㅋㅋㅋ" 를 출력하고 아니면 "안녕 후배!" 를 출력해라.

# %%
# [문제] input("이름: ") 으로 받고 비교(==)해봐라! ㅋㅋㅋ

# %% [markdown]
# ### Q10. BMI 맛보기
# 체중(kg)을 키(m)의 제곱으로 나눈다. 몸무게 70kg, 키 1.8m인 사람의 BMI를 소수점까지 구해라.

# %%
# [문제] 제곱 연산자는 ** 이다. ㅋㅋㅋ

# %% [markdown]
# ### Q11. 빛의 속도... 아니 시간 변환기
# 분(minute)을 입력받아 초(second)로 변환해라.

# %%
# [문제] 1분은 60초라는 팩트를 코드로 짜봐라! ㅋㅋㅋ

# %% [markdown]
# ### Q12. 팩트와 가짜뉴스 구분
# 어떤 문장을 입력받아 그 안에 "공산주의" 라는 단어가 있으면 "가짜뉴스 검거!" 라고 출력해라.

# %%
# [문제] '공산주의' in sentence 요롷게 쓰면 검거 가능하다 ㅋㅋㅋ
